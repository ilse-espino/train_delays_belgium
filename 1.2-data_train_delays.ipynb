# %%
#import libraries
import pandas as pd
import numpy as np

# %%
# apply same rules to all trian delays files
months = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]
df_train_delays = pd.DataFrame(columns=('DATDEP', 'TRAIN_NO', 'RELATION', 'TRAIN_SERV', 'PTCAR_NO',
       'LINE_NO_DEP', 'REAL_TIME_ARR', 'REAL_TIME_DEP', 'PLANNED_TIME_ARR',
       'PLANNED_TIME_DEP', 'DELAY_ARR', 'DELAY_DEP', 'RELATION_DIRECTION',
       'PTCAR_LG_NM_NL', 'LINE_NO_ARR', 'PLANNED_DATE_ARR', 'PLANNED_DATE_DEP',
       'REAL_DATE_ARR', 'REAL_DATE_DEP', 'departure', 'destination', 'delayed'))

for i in range(9):
       for j in range(12):
              df = pd.read_csv("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/20" + str(14+i) + "/Data_raw_punctuality_20" + str(14+i) + months[j] + ".csv")
              df['PTCAR_LG_NM_NL'][pd.isna(df.REAL_TIME_DEP)]
              df['departure'] = df.groupby(['DATDEP', 'TRAIN_NO'], sort=False)['PTCAR_LG_NM_NL'].transform('first')
              df['destination'] = df.groupby(['DATDEP', 'TRAIN_NO'], sort=False)['PTCAR_LG_NM_NL'].transform('last')
              df2 = df[df.PTCAR_LG_NM_NL == 'BRUSSEL-CENTRAAL']
              df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
              df_train_delays = df_train_delays.append(df2)
# Out:
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:11: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/20" + str(14+i) + "/Data_raw_punctuality_20" + str(14+i) + months[j] + ".csv")
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_delays = df_train_delays.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_32688/3678602390.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_train_delays = df_train_delays.append(df2)

# %%
# count the final rows
df_train_delays.count()
# Out:
# DATDEP                3183238
# TRAIN_NO              3183238
# RELATION              3183238
# TRAIN_SERV            3183238
# PTCAR_NO              3183238
# LINE_NO_DEP           3183081
# REAL_TIME_ARR         3183218
# REAL_TIME_DEP         3183097
# PLANNED_TIME_ARR      3182701
# PLANNED_TIME_DEP      3182569
# DELAY_ARR             3183231
# DELAY_DEP             3183160
# RELATION_DIRECTION    2666202
# PTCAR_LG_NM_NL        3183238
# LINE_NO_ARR           3183159
# PLANNED_DATE_ARR      3182701
# PLANNED_DATE_DEP      3182569
# REAL_DATE_ARR         3183218
# REAL_DATE_DEP         3183097
# departure             3183238
# destination           3183238
# delayed               3183238
# dtype: int64

# %%
# add year, month, day columns
df_train_delays["year"] = df_train_delays["DATDEP"].apply(lambda x: x[5:])
df_train_delays["month"] = df_train_delays["DATDEP"].apply(lambda x: x[2:5])
df_train_delays["day"] = df_train_delays["DATDEP"].apply(lambda x: x[:2])

# %%
df_train_delays["month"].unique()
# Out:
# array(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC'], dtype=object)

# %%
# change month to month number
df_train_delays["month"] = df_train_delays["month"].map({"JAN": "01", "FEB": "02", "MAR": "03", "APR": "04", "MAY": "05", "JUN": "06", "JUL": "07", "AUG": "08", "SEP": "09", "OCT": "10", "NOV": "11", "DEC": "12"})

# %%
df_train_delays.head()
# Out:
#         DATDEP TRAIN_NO RELATION TRAIN_SERV PTCAR_NO LINE_NO_DEP  \
# 17   01JAN2014       10      ICE  SNCB/NMBS      215         0/2
# 288  01JAN2014     1209      INT  SNCB/NMBS      215         0/6
# 313  01JAN2014     1210      INT  SNCB/NMBS      215         0/5
# 370  01JAN2014     1213      INT  SNCB/NMBS      215         0/6
# 401  01JAN2014     1217      INT  SNCB/NMBS      215         0/6
#
#     REAL_TIME_ARR REAL_TIME_DEP PLANNED_TIME_ARR PLANNED_TIME_DEP  ...  \
# 17       21:31:15      21:31:07         21:32:00         21:32:00  ...
# 288       9:58:51      10:01:11          9:59:00         10:01:00  ...
# 313       7:02:34       7:04:17          6:59:00          7:01:00  ...
# 370      10:57:53      11:00:59         10:59:00         11:01:00  ...
# 401      11:58:12      12:03:39         11:59:00         12:01:00  ...
#
#     PLANNED_DATE_ARR PLANNED_DATE_DEP REAL_DATE_ARR REAL_DATE_DEP  \
# 17         01JAN2014        01JAN2014     01JAN2014     01JAN2014
# 288        01JAN2014        01JAN2014     01JAN2014     01JAN2014
# 313        01JAN2014        01JAN2014     01JAN2014     01JAN2014
# 370        01JAN2014        01JAN2014     01JAN2014     01JAN2014
# 401        01JAN2014        01JAN2014     01JAN2014     01JAN2014
#
#         departure   destination delayed  year month day
# 17     HERGENRATH  BRUSSEL-ZUID   False  2014    01  01
# 288         ESSEN  BRUSSEL-ZUID   False  2014    01  01
# 313  BRUSSEL-ZUID         ESSEN   False  2014    01  01
# 370         ESSEN  BRUSSEL-ZUID   False  2014    01  01
# 401         ESSEN  BRUSSEL-ZUID   False  2014    01  01
#
# [5 rows x 25 columns]

# %%
# get the hour from the planned departure
df_train_delays["hour_time_dep"] = df_train_delays["PLANNED_TIME_DEP"].astype("datetime64").dt.round("H").dt.hour

# %%
#export the distinct destinations in order to get the regions
pd.DataFrame(df_train_delays['destination'].unique()).to_excel("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/train_stations.xlsx", index=False)

# %%
#export the distinct destinations in order to get the regions
pd.DataFrame(df_train_delays['departure'].unique()).to_excel("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/train_stations_dep.xlsx", index=False)

# %%
# import the train stations with regions
df_regions = pd.read_excel("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/train_stations_regions.xlsx")

# %%
# merge train delays with regions and drop train station column from regions df
final_df = pd.merge(df_train_delays, df_regions, how="left", left_on = ["destination"], right_on = ["train_stations" ])

final_df.drop(columns=["train_stations"])
# Out:
#             DATDEP TRAIN_NO RELATION TRAIN_SERV PTCAR_NO LINE_NO_DEP  \
# 0        01JAN2014       10      ICE  SNCB/NMBS      215         0/2
# 1        01JAN2014     1209      INT  SNCB/NMBS      215         0/6
# 2        01JAN2014     1210      INT  SNCB/NMBS      215         0/5
# 3        01JAN2014     1213      INT  SNCB/NMBS      215         0/6
# 4        01JAN2014     1217      INT  SNCB/NMBS      215         0/6
# ...            ...      ...      ...        ...      ...         ...
# 3183233  31DEC2022     9259    IC 35  SNCB/NMBS      215         0/3
# 3183234  31DEC2022     9411     THAL   THI-FACT      215         0/1
# 3183235  31DEC2022     9916     THAL   THI-FACT      215         0/2
# 3183236  31DEC2022     9303     THAL   THI-FACT      215         0/1
# 3183237  31DEC2022     9315     THAL   THI-FACT      215         0/1
#
#         REAL_TIME_ARR REAL_TIME_DEP PLANNED_TIME_ARR PLANNED_TIME_DEP  ...  \
# 0            21:31:15      21:31:07         21:32:00         21:32:00  ...
# 1             9:58:51      10:01:11          9:59:00         10:01:00  ...
# 2             7:02:34       7:04:17          6:59:00          7:01:00  ...
# 3            10:57:53      11:00:59         10:59:00         11:01:00  ...
# 4            11:58:12      12:03:39         11:59:00         12:01:00  ...
# ...               ...           ...              ...              ...  ...
# 3183233      17:48:13      17:50:50         17:48:00         17:49:00  ...
# 3183234       9:27:57       9:27:57          9:28:00          9:28:00  ...
# 3183235       9:19:25       9:19:25          9:04:00          9:04:00  ...
# 3183236       7:55:40       7:55:40          7:55:00          7:55:00  ...
# 3183237       9:59:06       9:59:06          9:55:00          9:55:00  ...
#
#         REAL_DATE_ARR REAL_DATE_DEP      departure    destination delayed  \
# 0           01JAN2014     01JAN2014     HERGENRATH   BRUSSEL-ZUID   False
# 1           01JAN2014     01JAN2014          ESSEN   BRUSSEL-ZUID   False
# 2           01JAN2014     01JAN2014   BRUSSEL-ZUID          ESSEN   False
# 3           01JAN2014     01JAN2014          ESSEN   BRUSSEL-ZUID   False
# 4           01JAN2014     01JAN2014          ESSEN   BRUSSEL-ZUID   False
# ...               ...           ...            ...            ...     ...
# 3183233     31DEC2022     31DEC2022   BRUSSEL-ZUID  NOORDERKEMPEN   False
# 3183234     31DEC2022     31DEC2022          HALLE     HERGENRATH   False
# 3183235     31DEC2022     31DEC2022  NOORDERKEMPEN          HALLE    True
# 3183236     31DEC2022     31DEC2022   BRUSSEL-ZUID  NOORDERKEMPEN   False
# 3183237     31DEC2022     31DEC2022          HALLE  NOORDERKEMPEN   False
#
#          year month day hour_time_dep                   region
# 0        2014    01  01          22.0  BRUSSELS-CAPITAL REGION
# 1        2014    01  01          10.0  BRUSSELS-CAPITAL REGION
# 2        2014    01  01           7.0                 FLANDERS
# 3        2014    01  01          11.0  BRUSSELS-CAPITAL REGION
# 4        2014    01  01          12.0  BRUSSELS-CAPITAL REGION
# ...       ...   ...  ..           ...                      ...
# 3183233  2022    12  31          18.0                 FLANDERS
# 3183234  2022    12  31           9.0                 WALLONIA
# 3183235  2022    12  31           9.0                 FLANDERS
# 3183236  2022    12  31           8.0                 FLANDERS
# 3183237  2022    12  31          10.0                 FLANDERS
#
# [3183238 rows x 27 columns]

# %%
# get weather data
df_weather = pd.read_pickle("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/weather_data.pkl")

# %%
final_df.dtypes
# Out:
# DATDEP                 object
# TRAIN_NO               object
# RELATION               object
# TRAIN_SERV             object
# PTCAR_NO               object
# LINE_NO_DEP            object
# REAL_TIME_ARR          object
# REAL_TIME_DEP          object
# PLANNED_TIME_ARR       object
# PLANNED_TIME_DEP       object
# DELAY_ARR              object
# DELAY_DEP              object
# RELATION_DIRECTION     object
# PTCAR_LG_NM_NL         object
# LINE_NO_ARR            object
# PLANNED_DATE_ARR       object
# PLANNED_DATE_DEP       object
# REAL_DATE_ARR          object
# REAL_DATE_DEP          object
# departure              object
# destination            object
# delayed                object
# year                   object
# month                  object
# day                    object
# hour_time_dep         float64
# train_stations         object
# region                 object
# dtype: object

# %%
# change year, month, and day data type to integer
final_df["year"] = final_df["year"].apply(lambda x: x[:2]).astype(int)
final_df["month"] = final_df["month"].apply(lambda x: x[:2]).astype(int)
final_df["day"] = final_df["day"].apply(lambda x: x[:2]).astype(int)

# %%
# merge train delays with weather data and drop duplicated columns
final_df_2 = pd.merge(final_df, df_weather, how="left", left_on = ["year", "month", "day", "hour_time_dep"], right_on = ["year", "month", "day", "time"])
final_df_2.drop(columns=["time", "DATDEP"], inplace=True)

# %%
final_df_2.head()
# Out:
#   TRAIN_NO RELATION TRAIN_SERV PTCAR_NO LINE_NO_DEP REAL_TIME_ARR  \
# 0       10      ICE  SNCB/NMBS      215         0/2      21:31:15
# 1       10      ICE  SNCB/NMBS      215         0/2      21:31:15
# 2       10      ICE  SNCB/NMBS      215         0/2      21:31:15
# 3       10      ICE  SNCB/NMBS      215         0/2      21:31:15
# 4       10      ICE  SNCB/NMBS      215         0/2      21:31:15
#
#   REAL_TIME_DEP PLANNED_TIME_ARR PLANNED_TIME_DEP DELAY_ARR  ... year month  \
# 0      21:31:07         21:32:00         21:32:00       -45  ...   20     1
# 1      21:31:07         21:32:00         21:32:00       -45  ...   20     1
# 2      21:31:07         21:32:00         21:32:00       -45  ...   20     1
# 3      21:31:07         21:32:00         21:32:00       -45  ...   20     1
# 4      21:31:07         21:32:00         21:32:00       -45  ...   20     1
#
#   day hour_time_dep train_stations                   region temperature  \
# 0   1          22.0   BRUSSEL-ZUID  BRUSSELS-CAPITAL REGION         9.0
# 1   1          22.0   BRUSSEL-ZUID  BRUSSELS-CAPITAL REGION         1.0
# 2   1          22.0   BRUSSEL-ZUID  BRUSSELS-CAPITAL REGION         6.0
# 3   1          22.0   BRUSSEL-ZUID  BRUSSELS-CAPITAL REGION        -0.0
# 4   1          22.0   BRUSSEL-ZUID  BRUSSELS-CAPITAL REGION         5.0
#
#   relative_humidity wind_speed wind_direction
# 0              84.0       35.0           18.0
# 1              78.0       29.0           20.0
# 2              84.0       19.0           13.0
# 3              93.0       19.0           21.0
# 4              91.0       22.0           26.0
#
# [5 rows x 31 columns]

# %%
# export to pickle
final_df_2.to_pickle("/Users/ilseeb/Desktop/Postgraduate/Train Punctuality Data/final_df.pkl")
