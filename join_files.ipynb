# %%
#import libraries
import pandas as pd
import numpy as np

# %%
months = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]
final_df = pd.DataFrame(columns=('DATDEP', 'TRAIN_NO', 'RELATION', 'TRAIN_SERV', 'PTCAR_NO',
       'LINE_NO_DEP', 'REAL_TIME_ARR', 'REAL_TIME_DEP', 'PLANNED_TIME_ARR',
       'PLANNED_TIME_DEP', 'DELAY_ARR', 'DELAY_DEP', 'RELATION_DIRECTION',
       'PTCAR_LG_NM_NL', 'LINE_NO_ARR', 'PLANNED_DATE_ARR', 'PLANNED_DATE_DEP',
       'REAL_DATE_ARR', 'REAL_DATE_DEP', 'destination', 'delayed'))

for i in range(12):
    df = pd.read_csv("/Users/ilseeb/Downloads/Train Punctuality Data/2014/Data_raw_punctuality_2014" + months[i] + ".csv")
    df['PTCAR_LG_NM_NL'][pd.isna(df.REAL_TIME_DEP)]
    df['destination'] = df.groupby(['DATDEP', 'TRAIN_NO'], sort=False)['PTCAR_LG_NM_NL'].transform('last')
    df2 = df[df.PTCAR_LG_NM_NL == 'BRUSSEL-CENTRAAL']
    df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
    final_df = final_df.append(df2)
# Out:
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:9: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/ilseeb/Downloads/Train Punctuality Data/2014/Data_raw_punctuality_2014" + months[i] + ".csv")
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['delayed'] = np.where(df2['DELAY_DEP'] > 360, True, False)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df2)
# /var/folders/07/rfr15gnj2vx9fng2s7h5322h0000gn/T/ipykernel_26559/2970129683.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final_df = final_df.append(df2)

# %%
final_df.count()
# Out:
# DATDEP                359264
# TRAIN_NO              359264
# RELATION              359264
# TRAIN_SERV            359264
# PTCAR_NO              359264
# LINE_NO_DEP           359251
# REAL_TIME_ARR         359264
# REAL_TIME_DEP         359251
# PLANNED_TIME_ARR      359262
# PLANNED_TIME_DEP      359249
# DELAY_ARR             359264
# DELAY_DEP             359264
# RELATION_DIRECTION     15141
# PTCAR_LG_NM_NL        359264
# LINE_NO_ARR           359264
# PLANNED_DATE_ARR      359262
# PLANNED_DATE_DEP      359249
# REAL_DATE_ARR         359264
# REAL_DATE_DEP         359251
# destination           359264
# delayed               359264
# dtype: int64
